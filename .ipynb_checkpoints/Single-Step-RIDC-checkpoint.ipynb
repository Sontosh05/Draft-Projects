# %%
using Plots
include("polyfit_function.jl")
include("Lagrange_interpolation.jl")
# Out:
# WARNING: using Polynomials.vander in module Main conflicts with an existing identifier.
# Lagrange (generic function with 1 method)

# %%
# Two-step Adams Bashforth Scheme (Explicit)

function ab2(f, tspan, y0, N)
    h = (tspan[2] - tspan[1]) / N
    t = Vector(range(tspan[1], tspan[2], length=N+1))
    y = zeros(N + 1, 1)
    y[1] = y0
    k1=h*f(t[1], y[1])
    k2=h*f(t[1]+h, y[1]+k1)
    y[2]=y[1]+0.5*(k1+k2)
    # Two -step AB steps
    for i in 1:(N-1)
        y[i + 2] = y[i + 1] + (3/2) *h* f(t[i+1], y[i+1]) - 0.5 *h* f(t[i], y[i])
    end

    return t, y
end
# Out:
# ab2 (generic function with 1 method)

# %%
function ridc_step(f, tspan, y0 , N)
    
 
    K = 2
    
    h = (tspan[2] - tspan[1]) / N
    
    # Embedding AB-2 into RIDC
    # AB-2 update takes the form 
    # y_(n+1)= y_n + (3/2)*h*f(t_n, y_n) - (1/2)*h*f(t_(n-1), y_(n-1)).
    
    y=zeros(1, N+1, K+1)
    
    t, y[1, :, 1]=ab2(f, tspan, y0, N) # storing the provisional solution
   
   for k in 1:K
        y[1, 1, k+1]=y0 # initial condition
        nfval=f(t, y[1, :, k]) # New function value
        
        # (2k+2) equi-spaced nodes are used where k is the iteration number. 
        
        # First step computed by Trapezoidal RK2 (Explicit)
        Qdr=Lagrange(t[1:(2*k+2)], nfval[1:(2*k+2)], t[1], t[2]) # Quadrature
        k1= h*(f(t[1], y[1, 1, k+1])- f(t[1], y[1, 1, k]))
        k2= h*(f(t[1] + h, y[1, 1, k+1] + k1 + Qdr) - f(t[1]+h, y[1, 2, k])) 
        
        y[1, 2, k+1]=y[1, 1, k+1] + k1/2 + k2/2 + Qdr
        
        
        
        # First nth steps
        for n in 3:(2*k+1)
            Q= Lagrange(t[1:(2*k+2)], nfval[1:(2*k+2)], t[n-1], t[n])
            b1= (3/2)* h*(f(t[n-1], y[1, n-1, k+1]) - f(t[n-1], y[1, n-1, k]))
            b2= (1/2)* h*(f(t[n-2], y[1, n-2, k+1]) - f(t[n-2], y[1, n-2, k]))
            y[1, n, k+1]= y[1, n-1, k+1] + b1 - b2 + Q
        end
        
        for j in (2*k+2):(N+1)
            Q = Lagrange(t[j-(2*k+1):j], nfval[j-(2*k+1):j], t[j-1], t[j])
            b1= (3/2)* h*(f(t[j-1], y[1, j-1, k+1]) - f(t[j-1], y[1, j-1, k]))
            b2= (1/2)* h*(f(t[j-2], y[1, j-2, k+1]) - f(t[j-2], y[1, j-2, k]))
            y[1, j, k+1]= y[1, j-1, k+1] + b1 - b2 + Q
        end
            
    end
    return y[1, N+1, K+1]
end
# Out:
# ridc_step (generic function with 1 method)

# %%
# Example 1: y'= , y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1

tspan=[0 15]


f(t, y)= - y .+ sin.(10*t)



# Exact Solution

exact = -(1/101)* exp(-tspan[2]) *(-111 +10*exp(tspan[2]) *cos(10*tspan[2])- exp(tspan[2]) *sin(10*tspan[2]))

p=8 # Parameter for various N values

q=6 # subinterval varying parameter

err1 = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
    
    
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err1[n, j] = abs(exact - y)
        
    end
    
end


plot(nsub, err1[1, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(1 - 1))", ylabel="Absolute Error",xticks=nsub, xformatter=x -> string(Int(round(x))))
pdeg = polyfit(log10.(nsub[:]), log10.(err1[1,:]),1)
print(" N=$(6 * 2^(1 - 1)), p= ", abs(pdeg[2]),"\n")
for l in 2:p
    plot!(nsub, err1[l, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(l - 1))", xlabel="Number of Sub intervals", ylabel="Absolute Error", xticks=nsub, xformatter=x -> string(Int(round(x))))
    pdeg = polyfit(log10.(nsub[:]), log10.(err1[l,:]),1)
    print(" N=$(6 * 2^(l - 1)), p= ", abs(pdeg[2]),"\n")
end
display(plot!(legend=:topright))

# %%
order1=zeros(p)
for i=1:p
    pdeg = polyfit(log10.(nsub[:]), log10.(err[i,:]),1)
    order1[i]=abs(pdeg[2])
end

plot(nval, order1, xaxis=:log, xlabel="N values", ylabel="Order of Convergence", title="Order of Convergence at K=2 iterations", xticks=nval)

# %%
# Example 1: y'= , y(0)=1; T in [0, T]

using Plots

y0=1.0


tspan=[0 5]


f(t, y)=  - t .* y .^2 



# Exact Solution

exact =  2 /(2+tspan[2]^2)

p=8 # Parameter for various N values

q=9 # subinterval varying parameter

err3 = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
     #N=12*n
    
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err3[n, j] = abs(exact - y)
        
    end
    
end


plot(nsub, err3[1, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(1 - 1))", ylabel="Absolute Error")
pdeg = polyfit(log10.(nsub[:]), log10.(err3[1,:]),1)
print(" N=$(6 * 2^(1 - 1)), p= ", abs(pdeg[2]),"\n")
for l in 2:p
    plot!(nsub, err3[l, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(l - 1))", xlabel="Number of Sub intervals", ylabel="Absolute Error")
    pdeg = polyfit(log10.(nsub[:]), log10.(err3[l,:]),1)
    print(" N=$(6 * 2^(l - 1)), p= ", abs(pdeg[2]),"\n")
end
display(plot!(legend=:topright))
# Out:
#  N=6, p= 4.802729242909992
#  N=12, p= 3.919869107881858
#  N=24, p= 3.10837500494276
#  N=48, p= 2.210552032005753
#  N=96, p= 1.3120287473881314
#  N=192, p= 0.5532826513150305
#  N=384, p= 0.15655999301735765
#  N=768, p= 0.2912952211716285

# %%
# Example 1: y'=lambda* y, y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1

tspan=[0 2]


f(t, y) = - y .^2



# Exact Solution

exact = 1/(1+ tspan[2])

p=6 # Parameter for various N values

q=6 # subinterval varying parameter

err2 = zeros(p, q)

nsub=zeros(q)

nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
        
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err2[n, j] = abs(exact - y)
        
    end
    
end


plot(nsub, err2[1, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(1 - 1))", ylabel="Absolute Error",xticks=nsub, xformatter=x -> string(Int(round(x))))
pdeg = polyfit(log10.(nsub[:]), log10.(err2[1,:]),1)
print(" N=$(6 * 2^(1 - 1)), p= ", abs(pdeg[2]),"\n")

for l in 2:p
    plot!(nsub, err2[l, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(l - 1))", xlabel="Number of Sub intervals", ylabel="Absolute Error", xticks=nsub, xformatter=x -> string(Int(round(x))))
    pdeg = polyfit(log10.(nsub[:]), log10.(err2[l,:]),1)
    print(" N=$(6 * 2^(l - 1)), p= ", abs(pdeg[2]),"\n")
end
display(plot!(legend=:topright))

# %%
# Example 1: y'= , y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1

tspan=[0 15]


f(t, y)= - 2 * t .* y .^2 



# Exact Solution

exact = 1/(1+tspan[2]^2)

p=6 # Parameter for various N values

q=7 # subinterval varying parameter

err2 = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err2[n, j] = abs(exact - y)
        
    end
    
end


plot(nsub, err2[1, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(1 - 1))", ylabel="Absolute Error",xticks=nsub, xformatter=x -> string(Int(round(x))))
pdeg = polyfit(log10.(nsub[:]), log10.(err2[1,:]),1)
print(" N=$(6 * 2^(1 - 1)), p= ", abs(pdeg[2]),"\n")

for l in 2:p
    plot!(nsub, err2[l, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(l - 1))", xlabel="Number of Sub intervals", ylabel="Absolute Error", xticks=nsub, xformatter=x -> string(Int(round(x))))
    pdeg = polyfit(log10.(nsub[:]), log10.(err2[l,:]),1)
    print(" N=$(6 * 2^(l - 1)), p= ", abs(pdeg[2]),"\n")
end
display(plot!(legend=:topright))

# %%
# Example 1: y'=lambda* y, y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1.0

tspan=[0 10]


f(t, y) = lambda * y



# Exact Solution

exact = y0 * exp.(lambda * tspan[2])

p=6 # Parameter for various N values

q=6 # subinterval varying parameter

err = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
    #N= 12*n
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err[n, j] = abs(exact - y)
        
    end
    
end

order=zeros(p)
for i=1:p
    pdeg = polyfit(log10.(nsub[:]), log10.(err[i,:]),1)
    order[i]=abs(pdeg[2])
end

# %%
plot(nval, order, xaxis=:log, xlabel="N values", ylabel="Order of Convergence", title="Order of Convergence at K=2 iterations", label="Order of Convergence", xticks=nval)

# %%
# Example 1: y'=lambda* y, y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1

tspan=[0 10]


f(t, y) = lambda * y



# Exact Solution

exact = y0 * exp.(lambda * tspan[2])

p=9 # Parameter for various N values

q=6 # subinterval varying parameter

err = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 6*2^(n-1)
    
    #N= 12*n
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err[n, j] = abs(exact - y)
        
    end
    
end


plot(nsub, err[1, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(1 - 1))", ylabel="Absolute Error",xticks=nsub, xformatter=x -> string(Int(round(x))))
pdeg = polyfit(log10.(nsub[:]), log10.(err[1,:]),1)
print(" N=$(6 * 2^(1 - 1)), p= ", abs(pdeg[2]),"\n")

for l in 2:p
    plot!(nsub, err[l, :], xaxis=:log, yaxis=:log,  label="N=$(6 * 2^(l - 1))", xlabel="Number of Sub intervals", ylabel="Absolute Error", xticks=nsub, xformatter=x -> string(Int(round(x))))
    pdeg = polyfit(log10.(nsub[:]), log10.(err[l,:]),1)
    print(" N=$(6 * 2^(l - 1)), p= ", abs(pdeg[2]),"\n")
end
display(plot!(legend=:topright))

# %%
# Example 2: y'= - y^3, y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1.0

tspan=[0 15]


f(t, y) = - y .^ 2


# Exact Solution

exact = 1/(1+ tspan[2])

p=5 # Parameter for various N values

q=5 # subinterval varying parameter

err = zeros(p, q)

nsub=zeros(q)
nval=zeros(p)

for n=1:p
    
    N= 3*2^(n)
     
    #N=12*n
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        err[n, j] = abs(exact - y)
        
    end
    
end

order=zeros(p)

for i=1:p
    pdeg = polyfit(log10.(nsub[:]), log10.(err[i,:]),1)
    order[i]=abs(pdeg[2])
end
plot(nval, order, xaxis=:log, xlabel="N values", ylabel="Order of Convergence", label="K=2 iterations", xticks=nval)

# %%
# Example 1: y'=lambda* y, y(0)=1; T in [0, T]

using Plots

y0=1.0

lambda= 1

tspan=[0 10]


f(t, y) = lambda * y



# Exact Solution

exact = y0 * exp.(lambda * tspan[2])

p=6 # Parameter for various N values

q=6 # subinterval varying parameter

err = zeros(p, 1)

nsub=zeros(q)
nval=zeros(p)
 
ly=zeros(q)
for n=1:p
    
    N= 6*2^(n-1)
    
    #N= 12*n
    
    nval[n]= N # store N's
    
    for j= 1:q
        
        sub = 2^j # Number of subinterval
        
        nsub[j]= sub # store subinterval
    
        ds = tspan[2] / sub # final time / # of subinterval (I fixed here after Tuesday's meeting)

        y0= 1.0
        
        y=y0
        
        for i in 1:sub
    
            t0 = (i - 1) * ds # initial time
            tf = i * ds   # final time
            
            y = ridc_step(f, [t0 tf], y, N)

        end
        
        ly[q]= y # last y of last subinterval
        
    end
    
    err[n, 1]= abs(exact- ly[end])
    
end


pdeg = polyfit(log10.(nval[:]), log10.(err[:]),1)
order=abs(pdeg[2])
