# %%
using Plots
include("polyfit_function.jl")
include("Lagrange_interpolation.jl")
include("LReg.jl")
# Out:
# WARNING: using Polynomials.vander in module Main conflicts with an existing identifier.
# LReg (generic function with 1 method)

# %% [markdown]
# # Heat Equation
#
# \begin{align}
#   \frac{\partial u}{\partial t} &= \alpha \frac{\partial^2 u}{\partial x^2},
#   \quad x\in[0,1], \quad t\in(0,2],\\
#   u(t,0) &= u(t,1)=0, \quad u(0,x) = x(1-x).
# \end{align}
#
# With the (IMEX) Central Finite Difference Discretization of the diffusion term and explicit time discretization, we have
#
# \begin{align*}
#   \frac{u^{n+1}_i - u^{n}_i}{\Delta t} = \alpha
#   \frac{u^{n+1}_{i+1} - 2u^{n+1}_i + u^{n+1}_{i-1}}{\Delta x^2}
# \end{align*}

# %%
# Solving the heat equation (IMEX-predictor)
function predictor(dx, dt, un)
    #Approximation of alpha D_xx u
    # un: takes the initial condtion
    n = length(un)
    alpha=1.0
    beta = alpha*(dt/dx^2)
    A = Array(Tridiagonal(fill(-beta,n-1),fill(1+2*beta,n),fill(-beta,n-1)))
    f=un
    return A\f
end
# Out:
# predictor (generic function with 1 method)

# %%
N = 100 # number of time intervals
M = 40 # number of (interior) spatial grid points

tspan = [0 2.0]
dt = (tspan[2] - tspan[1])/N
dx = 1.0/(M+1)
x = (1:M) .* dx
t = (0:N) .* dt

u0 = x .*(1 .-x)

u = zeros(M,N+1)
u[:,1] = u0

for n = 1:N
    u[:,n+1] = predictor(dx, dt, u[:,n])
end

surface(t, x, u, xlabel="t",ylabel="x")

# %%
# First-order Correction for IMEX (predictor)

# Convergence Study in time

M = 40  # number of (interior) spatial grid points
tspan = [0 2.0]
dx = 1.0 / (M + 1)
x = (1:M) .* dx
u0 = x .* (1 .- x)

K = 10
err = zeros(K-1, 1)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_final = zeros(M, K)

for k in 1:K
    N = 30 * 2^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    u = copy(u0)
    for n in 1:N
        u = predictor(dx, dt, u)
    end
    
    # Store only the final state for each k
    u_final[:, k] = copy(u)
end

# Calculate errors
for k in 2:K
    err[k-1] = norm(u_final[:, k] - u_final[:, k-1])
    nstore[k-1] = 20 * 2^(k-1)  # Store N values for analysis
end

# Polyfit
p = polyfit(log10.(nstore[:]),log10.(err[:]),1)
print("convergence order = ",abs(p[2]))

plot(nstore,err,xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",legend=false)
# Out:
# convergence order = 1.272627256524224

# %% [markdown]
# IMEX Predictor and One RIDC correction

# %%
# Define the right-hand side of the function Du

function rs(u,dx)
    # approximates D_xx u
    n = length(u)
    alpha=1.0
    beta = alpha/dx^2
    D = Array(Tridiagonal(fill(beta,n-1),fill(-2*beta,n),fill(beta,n-1)))
    
    return D*u
end
# Out:
# rs (generic function with 1 method)

# %%
# RIDC2 with IMEX correction

function RIDC2(N, tspan, u0, dx, dt)
    M=length(u0)
    #dt=(tspan[2]-tspan[1])/N
    u=zeros(M, N+1, 2)
    u[:, 1, 1]=u0
    u[:, 1, 2]=u0

    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    # Predictor (IMEX)
    for n=1:N
        f = u[:, n, 1]  # Right-hand side for the predictor
        u[:, n+1, 1] = A \ f  # Implicit solve for the predictor
    end

    # One correction RIDC2 (Implicit)
    for n=1:N
        
        # Quadrature Approximation
        quad_approx=0.5 .* dt .*(rs(u[:, n, 1], dx) .+ rs(u[:, n+1, 1], dx))
        # Assemble the right-hand side for the correction
        f = u[:, n, 2] .- dt .* rs(u[:, n+1, 1], dx) .+ quad_approx
        u[:, n+1, 2] = A \ f
    end
    
    return u
end
# Out:
# RIDC2 (generic function with 1 method)

# %%
# Convergence Study in time

X = 40  # number of (interior) spatial grid points
tspan = [0 2.0]
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = sin.(pi .* x)

K = 10
err = zeros(K-1, 2)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_store = zeros(X, K, 2)

for k in 1:K
    
    N = 100*3^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    
    u =RIDC2(N, tspan, u0, dx, dt)

    
    # Store only the final state for each k
    u_store[:, k, 1]=u[:, end, 1]
    u_store[:, k, 2] = u[:, end, 2]
end

# Calculate errors
for k in 2:K
    err[k-1, 1] = norm(u_store[:, k, 1] - u_store[:, k-1, 1])
    err[k-1, 2] = norm(u_store[:, k, 2] - u_store[:, k-1, 2])
    nstore[k-1] = 100*3^(k-1)  # Store N values for analysis
end

# Polyfit
pdeg = polyfit(log10.(nstore[:]),log10.(err[:, 1]),1)
print("convergence order = ",abs(pdeg[2]), "\n")

plot(nstore,err[:, 1],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="Predictor")
pdeg = polyfit(log10.(nstore[:]),log10.(err[:, 2]),1)
print("convergence order = ",abs(pdeg[2]), "\n")
plot!(nstore,err[:, 2],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="RIDC2")
display(plot!(legend=:topright))
# Out:
# convergence order = 1.0293451043257524
# convergence order = 2.0209381262643684

# %% [markdown]
# Two-Level Deferred Correction

# %%
# Reference Solution
function Ref(tspan, u0, dx, dt, N)
    
    M=length(u0)
    m=2 # Coarsenning factor
    DT=m*dt
    U=zeros(M, N+1, 2)
    U[:, 1, 1]=u0
    U[:, 1, 2]=u0

    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    for i=1:m:N
        U[:, i, 1]=U[:, i, 2]

        # F-Relaxation
        for j=i:i+1
            f = U[:, j, 1]
            U[:, j+1, 1]= A\f
        end

        # Coarse Correction
        
        # Quadrature Approximation
        
        quad_approx= DT .*((-1.0/12) *rs(U[:, i, 1], dx) .+ (2.0/3)* rs(U[:, i+1, 1], dx) .+ (5.0/12)* rs(U[:, i+m, 1], dx))
        
        #quad_approx= 0.5*DT .*(rs(U[:, i, 1], dx)  .+ rs(U[:, i+2, 1], dx)) # Trapezoidal
        
        # Assemble the right-hand side for the correction
        f = U[:, i, 2] .- DT .* rs(U[:, i+m, 1], dx) .+ quad_approx # Right-hand side RIDC for ut=uxx
        # Needs to redefine Matrix A for the coarse system 
        alpha = 1.0
        beta = alpha * (DT / dx^2) # DT
        A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))
        U[:, i+m, 2] = A \ f
    end
    return U
end
# Out:
# Ref (generic function with 1 method)

# %%
# Convergence Study in time for the two-level Reference Solution

X = 40  # number of (interior) spatial grid points
tspan = [0 2.0]
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = x .* (1 .- x)

K = 10
err = zeros(K-1, 2)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_store = zeros(X, K, 2)

for k in 1:K
    
    N = 10 * 2^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    
    u =Ref(tspan, u0, dx, dt, N)

    
    # Store only the final state for each k
    u_store[:, k, 1]=u[:, end, 1]
    u_store[:, k, 2] = u[:, end, 2]
end

# Calculate errors
for k in 2:K
    err[k-1, 1] = norm(u_store[:, k, 1] - u_store[:, k-1, 1])
    err[k-1, 2] = norm(u_store[:, k, 2] - u_store[:, k-1, 2])
    nstore[k-1] = 10 * 2^(k-1)  # Store N values for analysis
end

# Polyfit
pdeg = polyfit(log10.(nstore[:]),log10.(err[:, 2]),1)
print("convergence order = ",abs(pdeg[2]), "\n")

plot(nstore,err[:, 2],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="Reference Solution")
# Out:
# convergence order = 2.4337899713640074

# %%
function twolevel(tspan, u0, dx, dt, N, K)
    M=length(u0)
    m=2 # Coarsenning factor
    DT=m*dt
    u=zeros(M, N+1, K+1)
    u[:, 1, 1]=u0
    ps=3:m:N
    u[:, ps, 1]= rand(M, length(ps))
    up=zeros(M, N+1)
    up[:, 1]=u0
    
    # Set up of Matrix A for the fine mesh
    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    for k in 1:K

        u[:, 1, k+1]=u0

        # F-relaxation
        for i=1:m:N
            up[:, i]=u[:, i, k] # injection from the second level
            up[:, i+1]= A\up[:, i]
        end

        # C-relaxation
        for j=2:m:N
            up[:, j+1]=A\up[:, j]
        end

        # Coarse Grid Correction

        for n=1:m:N

            up[:, n]=  u[:, n, k]

            # Quadrature Approximation
            quad_approx= DT .*((-1.0/12) *rs(up[:, n], dx) .+ (2.0/3)* rs(up[:, n+1], dx) .+ (5.0/12)* rs(up[:, n+2], dx))
            # Assemble the right-hand side for the correction
            f = u[:, n, k+1] .- DT .* rs(up[:, n+m], dx) .+ quad_approx # Right-hand side RIDC
            
            # Needs to redefine Matrix A for the coarse system 
            alpha = 1.0
            beta = alpha * (DT / dx^2) # DT
            A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))
            u[:, n+m, k+1] = A \ f   
        end
    end
    return u
    
end
# Out:
# twolevel (generic function with 1 method)

# %%
# Convergence Study in time for the two-level Reference Solution

X = 40  # number of (interior) spatial grid points
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = x .* (1 .- x)
m=2
tspan = [0 2.0]
N=100
dt=(tspan[2]-tspan[1])/N
K=20
err=zeros(K+1)
U=Ref(tspan, u0, dx, dt, N)
u=twolevel(tspan, u0, dx, dt, N, K)
for k=1:K+1
    err[k] = norm(U[:, end, 2] .- u[:, end, k])
end
plot(0:K, err, yaxis=:log)

# %%
err
# Out:
# 21-element Vector{Float64}:
#  1.0532909540426828e-8
#  0.23062932592694962
#  0.020370438131510973
#  0.0018657702393550747
#  0.00017333841514476794
#  1.6845309821717488e-5
#  1.5755591938955937e-6
#  1.4794056260813957e-7
#  1.3418203579043235e-8
#  1.3551698576511574e-9
#  1.7871623450071157e-11
#  1.2984474111819907e-10
#  1.1966953027838007e-10
#  1.205103740145599e-10
#  1.204440901365637e-10
#  1.2044904088217235e-10
#  1.2044869227187855e-10
#  1.2044871532297267e-10
#  1.2044871389599491e-10
#  1.204487139787385e-10
#  1.2044871397416514e-10
