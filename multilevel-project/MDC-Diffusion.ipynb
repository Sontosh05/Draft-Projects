# %%
using Plots
include("polyfit_function.jl")
include("Lagrange_interpolation.jl")
include("LReg.jl")
include("Lagrange_Mat.jl")
# Out:
# Lagrange_Mat (generic function with 1 method)

# %% [markdown]
# # Heat Equation
#
# \begin{align}
#   \frac{\partial u}{\partial t} &= \alpha \frac{\partial^2 u}{\partial x^2},
#   \quad x\in[0,1], \quad t\in(0,2],\\
#   u(t,0) &= u(t,1)=0, \quad u(0,x) = x(1-x).
# \end{align}
#
# With the (IMEX) Central Finite Difference Discretization of the diffusion term and explicit time discretization, we have
#
# \begin{align*}
#   \frac{u^{n+1}_i - u^{n}_i}{\Delta t} = \alpha
#   \frac{u^{n+1}_{i+1} - 2u^{n+1}_i + u^{n+1}_{i-1}}{\Delta x^2}
# \end{align*}

# %%
# Solving the heat equation (IMEX-predictor)
function predictor(dx, dt, un)
    #Approximation of alpha D_xx u
    # un: takes the initial condtion
    n = length(un)
    alpha=1.0
    beta = alpha*(dt/dx^2)
    A = Array(Tridiagonal(fill(-beta,n-1),fill(1+2*beta,n),fill(-beta,n-1)))
    f=un 
    return A\f
end
# Out:
# predictor (generic function with 1 method)

# %%
N = 100 # number of time intervals
M = 40 # number of (interior) spatial grid points

tspan = [0 2.0]
dt = (tspan[2] - tspan[1])/N
dx = 1.0/(M+1)
x = (1:M) .* dx
t = (0:N) .* dt

u0 = x .*(1 .-x)

u = zeros(M,N+1)
u[:,1] = u0

for n = 1:N
    u[:,n+1] = predictor(dx, dt, u[:,n])
end

surface(t, x, u, xlabel="t",ylabel="x")

# %%
# First-order Correction for IMEX (predictor)

# Convergence Study in time

M = 80  # number of (interior) spatial grid points
tspan = [0 1.0]
dx = 1.0 / (M + 1)
x = (1:M) .* dx
u0 = x .* (1 .- x)

K = 10
err = zeros(K-1, 1)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_final = zeros(M, K)

for k in 1:K
    N =  10* 2^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    u = copy(u0)
    for n in 1:N
        u = predictor(dx, dt, u)
    end
    
    # Store only the final state for each k
    u_final[:, k] = copy(u)
end

# Calculate errors
for k in 2:K
    err[k-1] = norm(u_final[:, k] - u_final[:, k-1])
    nstore[k-1] =  10*2^(k-1)  # Store N values for analysis
end

# Polyfit
p = polyfit(log10.(nstore[:]),log10.(err[:]),1)
print("convergence order = ",abs(p[2]))

plot(nstore,err,xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",legend=false)

# %% [markdown]
# IMEX Predictor and One RIDC correction

# %%
# Define the right-hand side of the function Du

function rs(u,dx)
    # approximates D_xx u
    n = length(u)
    alpha=1.0
    beta = alpha/dx^2
    D = Array(Tridiagonal(fill(beta,n-1),fill(-2*beta,n),fill(beta,n-1)))
    
    return D*u
end
# Out:
# rs (generic function with 1 method)

# %%
# RIDC2 with IMEX correction

function RIDC2(N, tspan, u0, dx, dt)
    M=length(u0)
    #dt=(tspan[2]-tspan[1])/N
    t=(0:N)*dt
    u=zeros(M, N+1, 2)
    u[:, 1, 1]=u0
    u[:, 1, 2]=u0

    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    # Predictor (IMEX)
    for n=1:N
        f = u[:, n, 1]  # Right-hand side for the predictor
        u[:, n+1, 1] = A \ f  # Implicit solve for the predictor
    end

    # One correction RIDC2 (Implicit)
    for n=1:N
        
        # Compute residuals for time steps n and n+1 separately
        rs_n = rs(u[:, n, 1], dx)      # 
        rs_n1 = rs(u[:, n+1, 1], dx)   # 

        # Perform Lagrange interpolation using the residuals
        rs_values = hcat(rs_n, rs_n1)  # Matrix of residuals (M, 2)
        quad_approx = Lagrange_Mat(t[n:n+1], rs_values, t[n], t[n+1])

        f = u[:, n, 2] .- dt .* rs(u[:, n+1, 1], dx) .+ quad_approx
        u[:, n+1, 2] = A \ f
    end
    
    return u
end

# %%
# Convergence Study in time

X = 80  # number of (interior) spatial grid points
tspan = [0 1.0]
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = sin.(pi .* x)

K = 10
err = zeros(K-1, 2)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_store = zeros(X, K, 2)

for k in 1:K
    
    N = 10*2^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    
    u =RIDC2(N, tspan, u0, dx, dt)

    
    # Store only the final state for each k
    u_store[:, k, 1]=u[:, end, 1]
    u_store[:, k, 2] = u[:, end, 2]
end

# Calculate errors
for k in 2:K
    err[k-1, 1] = norm(u_store[:, k, 1] - u_store[:, k-1, 1])
    err[k-1, 2] = norm(u_store[:, k, 2] - u_store[:, k-1, 2])
    nstore[k-1] = 10*2^(k-1)  # Store N values for analysis
end

# Polyfit
pdeg = polyfit(log10.(nstore[:]),log10.(err[:, 1]),1)
print("convergence order = ",abs(pdeg[2]), "\n")

plot(nstore,err[:, 1],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="Predictor")
pdeg = polyfit(log10.(nstore[:]),log10.(err[:, 2]),1)
print("convergence order = ",abs(pdeg[2]), "\n")
plot!(nstore,err[:, 2],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="RIDC2")
display(plot!(legend=:topright))
# Out:
# UndefVarError: `RIDC2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[9]:20

# %%
N = 100 # number of time intervals
M = 40 # number of (interior) spatial grid points

tspan = [0 1.0]
dt = (tspan[2] - tspan[1])/N
dx = 1.0/(M+1)
x = (1:M) .* dx
t = (0:N) .* dt

u0 = x .*(1 .-x)

u=RIDC2(N, tspan, u0, dx, dt)
surface(t, x, u[:, :, 2], xlabel="t",ylabel="x")

# %% [markdown]
# Two-Level Deferred Correction

# %%
# Reference Solution
function Ref(tspan, u0, dx, dt, N)
    
    M=length(u0)
    m=2 # Coarsenning factor
    t=(0:N)*dt
    DT=m*dt
    U=zeros(M, N+1, 2)
    
    U[:, 1, 1]=u0
    U[:, 1, 2]=u0

    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    for i=1:m:N
        U[:, i, 1]=U[:, i, 2]

        # F-Relaxation
        for j=i:i+1
            U[:, j+1, 1]= A \ U[:, j, 1]
        end

        # Coarse Correction


        # Right-hand-side function value
        rs_n = rs(U[:, i, 1], dx)      
        rs_n1 = rs(U[:, i+1, 1], dx) 
        rs_n2 = rs(U[:, i+2, 1], dx) 

        # Perform Lagrange interpolation 
        rs_values = hcat(rs_n, rs_n1, rs_n2)  # Matrix of residuals (M, 3)
        
        quad_approx = Lagrange_Mat(t[i:i+2], rs_values, t[i], t[i+2])

        
        # Assemble the right-hand side for the correction
        f = U[:, i, 2] .- DT .* rs(U[:, i+m, 1], dx) .+ quad_approx # Right-hand side RIDC for ut=uxx
        # Needs to redefine Matrix A for the coarse system 
        alpha = 1.0
        beta1 = alpha * (DT / dx^2) # DT
        B = Array(Tridiagonal(fill(-beta1, M-1), fill(1 + 2*beta1, M), fill(-beta1, M-1)))
        U[:, i+m, 2] = B \ f
    end
    return U
end
# Out:
# Ref (generic function with 1 method)

# %%
# Convergence Study in time for the two-level Reference Solution

X = 80  # number of (interior) spatial grid points
tspan = [0 1.0]
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = x .*(1 .- x)

K = 10
err = zeros(K-1)  # we will compare successive solutions
nstore = zeros(K-1, 1)
u_store = zeros(X, K)

for k in 1:K
    
    N = 20* 2^k  # number of time intervals
    #nstore[k]= N
    dt = (tspan[2] - tspan[1]) / N
    
    u =Ref(tspan, u0, dx, dt, N)

    
    # Store only the final state for each k
    u_store[:, k] = u[:, end, 2]
end

# Calculate errors
for k in 2:K
    err[k-1] = norm(u_store[:, k] - u_store[:, k-1])
    nstore[k-1] = 20*2^(k-1)  # Store N values for analysis
end

# Polyfit
pdeg = polyfit(log10.(nstore[:]),log10.(err[:]),1)
print("convergence order = ",abs(pdeg[2]), "\n")

plot(nstore,err[:],xaxis=:log,yaxis=:log,xlabel="N",ylabel="error",label="Reference Solution")
# Out:
# convergence order = 1.8848404238603496

# %%
N = 2000 # number of time intervals
M = 800 # number of (interior) spatial grid points

tspan = [0 2.0]
dt = (tspan[2] - tspan[1])/N
dx = 1.0/(M+1)
x = (1:M) .* dx
t = (0:N) .* dt

u0 = x .*(1 .-x)

u=Ref(tspan, u0, dx, dt, N)
surface(t, x, u[:, :, 2], xlabel="t",ylabel="x")

# %%
function twolevel(tspan, u0, dx, dt, N, K)
    
    M=length(u0)
    m=2 # Coarsenning factor
    DT=m*dt
    t=(0:N)*dt
    u=zeros(M, N+1, K+1)
    u[:, 1, 1]=u0
    ps=3:m:N
    u[:, ps, 1]= rand(M, length(ps))
    up=zeros(M, N+1)
    up[:, 1]=u0
    
    # Set up of Matrix A for the fine mesh
    alpha = 1.0
    beta = alpha * (dt / dx^2)
    A = Array(Tridiagonal(fill(-beta, M-1), fill(1 + 2*beta, M), fill(-beta, M-1)))

    for k in 1:K

        u[:, 1, k+1]=u0

        # F-relaxation
        for i=1:m:N
            up[:, i]=u[:, i, k] # injection from the second level
            up[:, i+1]= A\up[:, i]
        end

        # C-relaxation
        for j=2:m:N
            up[:, j+1]=A\up[:, j]
        end

        # Coarse Grid Correction

        for n=1:m:N

            up[:, n]=  u[:, n, k]


            rs_n = rs(up[:, n], dx)      
            rs_n1 = rs(up[:, n+1], dx) 
            rs_n2 = rs(up[:, n+2], dx) 

            # Perform Lagrange interpolation using the residuals
            rs_values = hcat(rs_n, rs_n1, rs_n2)  # Matrix of residuals (M, 3)
        
            quad_approx = Lagrange_Mat(t[n:n+2], rs_values, t[n], t[n+2])


            # Assemble the right-hand side for the correction
            f = u[:, n, k+1] .- DT .* rs(up[:, n+m], dx) .+ quad_approx # Right-hand side RIDC
            
            # Needs to redefine Matrix A for the coarse system 
            alpha = 1.0
            beta1 = alpha * (DT / dx^2) # DT
            B = Array(Tridiagonal(fill(-beta1, M-1), fill(1 + 2*beta1, M), fill(-beta1, M-1)))
            u[:, n+m, k+1] = B \ f   
        end
    end
    return u
    
end
# Out:
# twolevel (generic function with 1 method)

# %%
# Convergence Study in time for the two-level Reference Solution

X = 100   # number of (interior) spatial grid points
dx = 1.0 / (X + 1)
x = (1:X) .* dx
u0 = x .* (1 .- x)
m=2
tspan = [0 1.0]
N=600
dt=(tspan[2]-tspan[1])/N
K=30
err=zeros(K+1)
U=Ref(tspan, u0, dx, dt, N)
u=twolevel(tspan, u0, dx, dt, N, K)
for k=1:K+1
    err[k] = norm(U[:, end, 2] .- u[:, end, k]) .+10^(-16)
end
plot(0:K, err, yaxis=:log, label="Convergence")
